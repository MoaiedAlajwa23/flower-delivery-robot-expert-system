# %%
from homework2.helper import DuplicationRulesMixin
from homework2.helper import ReportingRulesMixin
from homework2.heuristic import HeuristicRulesMixin
from homework2.initial_state import InitialStateMixin1
from homework2.rules import MovementRulesMixin1
from homework2.facts import *
from homework2.load import LoadingRulesMixin
from homework2.search import SearchRulesMixin
from homework2.search_control import SearchControlMixin
from homework2.unload import UnloadingRulesMixin

# %%
class FlowerRobotEngine1(InitialStateMixin1, MovementRulesMixin1, DuplicationRulesMixin,LoadingRulesMixin,UnloadingRulesMixin,SearchRulesMixin,ReportingRulesMixin,HeuristicRulesMixin,SearchControlMixin):

    def __init__(self):
        super().__init__()

if __name__ == "__main__":
    engine = FlowerRobotEngine1()
    engine.reset()

    engine.declare(SystemPhase(step="search"))

    print("Finding the best path with A*...")
    print("waiting...\n")

    engine.run()
# Out:
# Finding the best path with A*...
# waiting...
#
# [A* Selection] - Best node selected for expansion: NID 0 with F = 25.0
# New child state generated successfully.
#    - Parent Node (NID: 0): Robot was at (X:1, Y:3)
#    - Action Executed: Move Right (move_right)
#    - Child Node (NID: 1): Robot is now at (X:2, Y:3)
#    - Actual Cost (g) is now: 1
# --------------------------------------------------
# New child state generated successfully.
#    - Parent Node (NID: 0): Robot was at (X:1, Y:3)
#    - Action Executed: Move Up (move_up)
#    - Child Node (NID: 2): Robot is now at (X:1, Y:4)
#    - Actual Cost (g) is now: 1
# --------------------------------------------------
# New child state generated successfully.
#    - Parent Node (NID: 0): Robot was at (X:1, Y:3)
#    - Action Executed: Move Down (move_down)
#    - Child Node (NID: 3): Robot is now at (X:1, Y:2)
#    - Actual Cost (g) is now: 1
# --------------------------------------------------
# New child state generated successfully.
#    - Parent Node (NID: 0): Robot was at (X:1, Y:3)
#    - Action Executed: Move Left (move_left)
#    - Child Node (NID: 4): Robot is now at (X:0, Y:3)
#    - Actual Cost (g) is now: 1
# --------------------------------------------------
# [A* Selection] - Best node selected for expansion: NID 4 with F = 26.0
# New child state generated successfully.
#    - Parent Node (NID: 4): Robot was at (X:0, Y:3)
#    - Action Executed: Move Right (move_right)
#    - Child Node (NID: 5): Robot is now at (X:1, Y:3)
#    - Actual Cost (g) is now: 2
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      11
#      12     print("Finding the best path with A*...")
#      13     print("waiting...\n")
#      14
# ---> 15     engine.run()
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\engine.py:140, in KnowledgeEngine.run(self, steps)
#     137 execution = 0
#     138 while steps > 0 and self.running:
# --> 140     added, removed = self.get_activations()
#     141     self.strategy.update_agenda(self.agenda, added, removed)
#     143     if watchers.worth('AGENDA', 'DEBUG'):  # pragma: no cover
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\engine.py:115, in KnowledgeEngine.get_activations(self)
#     111 def get_activations(self):
#     112     """
#     113     Return activations
#     114     """
# --> 115     return self.matcher.changes(*self.facts.changes)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\__init__.py:57, in ReteMatcher.changes(self, adding, deleting)
#      55 if adding is not None:
#      56     for added in adding:
# ---> 57         self.root_node.add(added)
#      59 added = list()
#      60 removed = list()
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:41, in BusNode.add(self, fact)
#      39 MATCHER.debug("<BusNode> added %r", token)
#      40 for child in self.children:
# ---> 41     child.callback(token)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:46, in OneInputNode.activate(self, token)
#      42 if watchers.worth('MATCHER', 'DEBUG'):  # pragma: no cover
#      43     watchers.MATCHER.debug(
#      44         "Node <%s> activated with token %r", self, token)
# ---> 46 return self._activate(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:133, in FeatureTesterNode._activate(self, token)
#     131     token.context.update(match)
#     132 for child in self.children:
# --> 133     child.callback(token)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:46, in OneInputNode.activate(self, token)
#      42 if watchers.worth('MATCHER', 'DEBUG'):  # pragma: no cover
#      43     watchers.MATCHER.debug(
#      44         "Node <%s> activated with token %r", self, token)
# ---> 46 return self._activate(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:133, in FeatureTesterNode._activate(self, token)
#     131     token.context.update(match)
#     132 for child in self.children:
# --> 133     child.callback(token)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:46, in OneInputNode.activate(self, token)
#      42 if watchers.worth('MATCHER', 'DEBUG'):  # pragma: no cover
#      43     watchers.MATCHER.debug(
#      44         "Node <%s> activated with token %r", self, token)
# ---> 46 return self._activate(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:133, in FeatureTesterNode._activate(self, token)
#     131     token.context.update(match)
#     132 for child in self.children:
# --> 133     child.callback(token)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:72, in TwoInputNode.activate_right(self, token)
#      69 """Make a copy of the received token and call `_activate_right`."""
#      70 watchers.MATCHER.debug(
#      71     "Node <%s> activated right with token %r", self, token)
# ---> 72 return self._activate_right(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:227, in OrdinaryMatchNode._activate_right(self, token)
#     225 def _activate_right(self, token):
#     226     """Node right activation."""
# --> 227     self.__activation(token,
#     228                       self.right_memory,
#     229                       self.left_memory,
#     230                       is_left=False)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:211, in OrdinaryMatchNode.__activation(self, token, branch_memory, matching_memory, is_left)
#     206     newtoken = Token(token.tag,
#     207                      token.data | other_data,
#     208                      newcontext)
#     210     for child in self.children:
# --> 211         child.callback(newtoken)
#     212 else:
#     213     MATCH.debug("%s (%s | %s) = False",
#     214                 self.__class__.__name__,
#     215                 left_context,
#     216                 right_context)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:61, in TwoInputNode.activate_left(self, token)
#      58 """Make a copy of the received token and call `_activate_left`."""
#      59 watchers.MATCHER.debug(
#      60     "Node <%s> activated left with token %r", self, token)
# ---> 61 return self._activate_left(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:220, in OrdinaryMatchNode._activate_left(self, token)
#     218 def _activate_left(self, token):
#     219     """Node left activation."""
# --> 220     self.__activation(token,
#     221                       self.left_memory,
#     222                       self.right_memory,
#     223                       is_left=True)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:211, in OrdinaryMatchNode.__activation(self, token, branch_memory, matching_memory, is_left)
#     206     newtoken = Token(token.tag,
#     207                      token.data | other_data,
#     208                      newcontext)
#     210     for child in self.children:
# --> 211         child.callback(newtoken)
#     212 else:
#     213     MATCH.debug("%s (%s | %s) = False",
#     214                 self.__class__.__name__,
#     215                 left_context,
#     216                 right_context)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:61, in TwoInputNode.activate_left(self, token)
#      58 """Make a copy of the received token and call `_activate_left`."""
#      59 watchers.MATCHER.debug(
#      60     "Node <%s> activated left with token %r", self, token)
# ---> 61 return self._activate_left(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:220, in OrdinaryMatchNode._activate_left(self, token)
#     218 def _activate_left(self, token):
#     219     """Node left activation."""
# --> 220     self.__activation(token,
#     221                       self.left_memory,
#     222                       self.right_memory,
#     223                       is_left=True)
#
#     [... skipping similar frames: OrdinaryMatchNode.__activation at line 211 (2 times), OrdinaryMatchNode._activate_left at line 220 (2 times), TwoInputNode.activate_left at line 61 (2 times)]
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:211, in OrdinaryMatchNode.__activation(self, token, branch_memory, matching_memory, is_left)
#     206     newtoken = Token(token.tag,
#     207                      token.data | other_data,
#     208                      newcontext)
#     210     for child in self.children:
# --> 211         child.callback(newtoken)
#     212 else:
#     213     MATCH.debug("%s (%s | %s) = False",
#     214                 self.__class__.__name__,
#     215                 left_context,
#     216                 right_context)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\abstract.py:61, in TwoInputNode.activate_left(self, token)
#      58 """Make a copy of the received token and call `_activate_left`."""
#      59 watchers.MATCHER.debug(
#      60     "Node <%s> activated left with token %r", self, token)
# ---> 61 return self._activate_left(token.copy())
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:220, in OrdinaryMatchNode._activate_left(self, token)
#     218 def _activate_left(self, token):
#     219     """Node left activation."""
# --> 220     self.__activation(token,
#     221                       self.left_memory,
#     222                       self.right_memory,
#     223                       is_left=True)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\nodes.py:206, in OrdinaryMatchNode.__activation(self, token, branch_memory, matching_memory, is_left)
#     202     if not isinstance(k, tuple):
#     203         # Negated value are not needed any further
#     204         newcontext[k] = v
# --> 206 newtoken = Token(token.tag,
#     207                  token.data | other_data,
#     208                  newcontext)
#     210 for child in self.children:
#     211     child.callback(newtoken)
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\token.py:55, in Token.__new__(cls, tag, data, context)
#      51 try:
#      52     assert isinstance(tag, cls.TagType), \
#      53         "tag must be of `Token.TagType` type"
#      54     assert (isinstance(data, Fact) or
# ---> 55             all(isinstance(f, Fact) for f in data)), \
#      56         "data must be either Fact or iterable of Facts"
#      57     assert isinstance(context, Mapping)
#      58 except AssertionError as exc:
#
# File ~\PycharmProjects\kbs\KBS_1\.venv\Lib\site-packages\experta\matchers\rete\token.py:55, in <genexpr>(.0)
#      51 try:
#      52     assert isinstance(tag, cls.TagType), \
#      53         "tag must be of `Token.TagType` type"
#      54     assert (isinstance(data, Fact) or
# ---> 55             all(isinstance(f, Fact) for f in data)), \
#      56         "data must be either Fact or iterable of Facts"
#      57     assert isinstance(context, Mapping)
#      58 except AssertionError as exc:
#
# KeyboardInterrupt:
